# %%
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
#定义保存或载入数据集的路径
path = "./datasets"

#下载并定义数据集
train_data = MNIST(root=path, train=True, transform=ToTensor(), download=True)
test_data = MNIST(root=path, train=False, transform=ToTensor(), download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:15<00:00, 620kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 98.9kB/s]
# 100%|██████████| 1.65M/1.65M [00:02<00:00, 784kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 972kB/s]

# %%
#定义如何枚举数据集
from torch.utils.data import DataLoader
train_loader = DataLoader(dataset=train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=64, shuffle=False)
print(train_loader)
print(test_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x000001B83E711CA0>
# <torch.utils.data.dataloader.DataLoader object at 0x000001B83E523580>
